# %% [markdown]
# # Predicting Dengue Fever Cases using weather data via Catboost Algorithm

# %% [markdown]
# ### Introduction
#
# This project aims to tackle the Dengue Fever Challenge posted on Driven Data.
# Five steps are included in this markdown:
# 1. importing packages and reading data from source
# 2. conducting basic EDA (Exploration Data Analysis)
# 3. feature engineering
# 4. train a model and test result simply using training data
# 5. train the model again using all training data and do prediction for the 'submit' set

# %% [markdown]
# ### Step 1: importing packages and reading data from source

# %%
# import packages
import pandas as pd
import numpy as np
import os 
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as MAE
from catboost import CatBoostRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-143-cbb6ae527cd5> in <module>()
#       8 from sklearn.model_selection import train_test_split
#       9 from sklearn.metrics import mean_absolute_error as MAE
# ---> 10 from catboost import CatBoostRegressor
#
# ModuleNotFoundError: No module named 'catboost'

# %%
# reading data
path = os.getcwd() + "/Data/"

data = {}
for file in os.listdir(path):
    data[re.sub(".csv", "", file)] = pd.read_csv(path + file)

training_X = data.pop("DengAI_Predicting_Disease_Spread_-_Training_Data_Features")
training_Y = data.pop("DengAI_Predicting_Disease_Spread_-_Training_Data_Labels")
submit_X = data.pop("DengAI_Predicting_Disease_Spread_-_Test_Data_Features")
submit_Y = data.pop("DengAI_Predicting_Disease_Spread_-_Submission_Format")

# joining data for train_test_split in the later stage
training = training_X.merge(training_Y, on=['city', 'year', 'weekofyear'], how='left')
submit = submit_X.merge(submit_Y, on=['city', 'year', 'weekofyear'], how='left')

# %% [markdown]
# ### Step 2: conduct basic EDA (Exploratory Data Analysis)

# %%
# check the shape of training data
training.shape
# Out:
# (1456, 25)

# %%
# check the shape of submission data
submit.shape
# Out:
# (416, 25)

# %%
# take a look at the training data
training.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k     ...       \
# 0  0.177617                 12.42             297.572857     ...
# 1  0.155486                 22.82             298.211429     ...
# 2  0.170843                 34.54             298.781429     ...
# 3  0.235886                 15.36             298.987143     ...
# 4  0.247340                  7.52             299.518571     ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# 1                             77.368571                         22.82
# 2                             82.052857                         34.54
# 3                             80.337143                         15.36
# 4                             80.460000                          7.52
#
#    reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                              14.012857           2.628571
# 1                              15.372857           2.371429
# 2                              16.848571           2.300000
# 3                              16.672857           2.428571
# 4                              17.210000           3.014286
#
#    station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0           25.442857                 6.900000                29.4
# 1           26.714286                 6.371429                31.7
# 2           26.714286                 6.485714                32.2
# 3           27.471429                 6.771429                33.3
# 4           28.942857                 9.371429                35.0
#
#    station_min_temp_c  station_precip_mm  total_cases
# 0                20.0               16.0            4
# 1                22.2                8.6            5
# 2                22.8               41.4            4
# 3                23.3                4.0            3
# 4                23.9                5.8            6
#
# [5 rows x 25 columns]

# %%
# take a look at the submission data
submit.head()
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  2008          18      2008-04-29  -0.0189 -0.018900  0.102729
# 1   sj  2008          19      2008-05-06  -0.0180 -0.012400  0.082043
# 2   sj  2008          20      2008-05-13  -0.0015       NaN  0.151083
# 3   sj  2008          21      2008-05-20      NaN -0.019867  0.124329
# 4   sj  2008          22      2008-05-27   0.0568  0.039833  0.062267
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k     ...       \
# 0  0.091200                 78.60             298.492857     ...
# 1  0.072314                 12.56             298.475714     ...
# 2  0.091529                  3.66             299.455714     ...
# 3  0.125686                  0.00             299.690000     ...
# 4  0.075914                  0.76             299.780000     ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             78.781429                         78.60
# 1                             78.230000                         12.56
# 2                             78.270000                          3.66
# 3                             73.015714                          0.00
# 4                             74.084286                          0.76
#
#    reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                              15.918571           3.128571
# 1                              15.791429           2.571429
# 2                              16.674286           4.428571
# 3                              15.775714           4.342857
# 4                              16.137143           3.542857
#
#    station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0           26.528571                 7.057143                33.3
# 1           26.071429                 5.557143                30.0
# 2           27.928571                 7.785714                32.8
# 3           28.057143                 6.271429                33.3
# 4           27.614286                 7.085714                33.3
#
#    station_min_temp_c  station_precip_mm  total_cases
# 0                21.7               75.2            0
# 1                22.2               34.3            0
# 2                22.8                3.0            0
# 3                24.4                0.3            0
# 4                23.3               84.1            0
#
# [5 rows x 25 columns]

# %%
# check datatypes of each column
training.dtypes
# Out:
# city                                             object
# year                                              int64
# weekofyear                                        int64
# week_start_date                          datetime64[ns]
# ndvi_ne                                         float64
# ndvi_nw                                         float64
# ndvi_se                                         float64
# ndvi_sw                                         float64
# precipitation_amt_mm                            float64
# reanalysis_air_temp_k                           float64
# reanalysis_avg_temp_k                           float64
# reanalysis_dew_point_temp_k                     float64
# reanalysis_max_air_temp_k                       float64
# reanalysis_min_air_temp_k                       float64
# reanalysis_precip_amt_kg_per_m2                 float64
# reanalysis_relative_humidity_percent            float64
# reanalysis_sat_precip_amt_mm                    float64
# reanalysis_specific_humidity_g_per_kg           float64
# reanalysis_tdtr_k                               float64
# station_avg_temp_c                              float64
# station_diur_temp_rng_c                         float64
# station_max_temp_c                              float64
# station_min_temp_c                              float64
# station_precip_mm                               float64
# total_cases                                       int64
# quarter                                           int64
# month                                             int64
# day                                               int64
# dtype: object

# %%
# check summary of the training data
training.describe(include='all')
# Out:
#         city         year   weekofyear      week_start_date      ndvi_ne  \
# count   1456  1456.000000  1456.000000                 1456  1262.000000
# unique     2          NaN          NaN                 1049          NaN
# top       sj          NaN          NaN  2005-01-29 00:00:00          NaN
# freq     936          NaN          NaN                    2          NaN
# first    NaN          NaN          NaN  1990-04-30 00:00:00          NaN
# last     NaN          NaN          NaN  2010-06-25 00:00:00          NaN
# mean     NaN  2001.031593    26.503434                  NaN     0.142294
# std      NaN     5.408314    15.019437                  NaN     0.140531
# min      NaN  1990.000000     1.000000                  NaN    -0.406250
# 25%      NaN  1997.000000    13.750000                  NaN     0.044950
# 50%      NaN  2002.000000    26.500000                  NaN     0.128817
# 75%      NaN  2005.000000    39.250000                  NaN     0.248483
# max      NaN  2010.000000    53.000000                  NaN     0.508357
#
#             ndvi_nw      ndvi_se      ndvi_sw  precipitation_amt_mm  \
# count   1404.000000  1434.000000  1434.000000           1443.000000
# unique          NaN          NaN          NaN                   NaN
# top             NaN          NaN          NaN                   NaN
# freq            NaN          NaN          NaN                   NaN
# first           NaN          NaN          NaN                   NaN
# last            NaN          NaN          NaN                   NaN
# mean       0.130553     0.203783     0.202305             45.760388
# std        0.119999     0.073860     0.083903             43.715537
# min       -0.456100    -0.015533    -0.063457              0.000000
# 25%        0.049217     0.155087     0.144209              9.800000
# 50%        0.121429     0.196050     0.189450             38.340000
# 75%        0.216600     0.248846     0.246982             70.235000
# max        0.454429     0.538314     0.546017            390.600000
#
#         reanalysis_air_temp_k     ...       reanalysis_tdtr_k  \
# count             1446.000000     ...             1446.000000
# unique                    NaN     ...                     NaN
# top                       NaN     ...                     NaN
# freq                      NaN     ...                     NaN
# first                     NaN     ...                     NaN
# last                      NaN     ...                     NaN
# mean               298.701852     ...                4.903754
# std                  1.362420     ...                3.546445
# min                294.635714     ...                1.357143
# 25%                297.658929     ...                2.328571
# 50%                298.646429     ...                2.857143
# 75%                299.833571     ...                7.625000
# max                302.200000     ...               16.028571
#
#         station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# count          1413.000000              1413.000000         1436.000000
# unique                 NaN                      NaN                 NaN
# top                    NaN                      NaN                 NaN
# freq                   NaN                      NaN                 NaN
# first                  NaN                      NaN                 NaN
# last                   NaN                      NaN                 NaN
# mean             27.185783                 8.059328           32.452437
# std               1.292347                 2.128568            1.959318
# min              21.400000                 4.528571           26.700000
# 25%              26.300000                 6.514286           31.100000
# 50%              27.414286                 7.300000           32.800000
# 75%              28.157143                 9.566667           33.900000
# max              30.800000                15.800000           42.200000
#
#         station_min_temp_c  station_precip_mm  total_cases      quarter  \
# count          1442.000000        1434.000000  1456.000000  1456.000000
# unique                 NaN                NaN          NaN          NaN
# top                    NaN                NaN          NaN          NaN
# freq                   NaN                NaN          NaN          NaN
# first                  NaN                NaN          NaN          NaN
# last                   NaN                NaN          NaN          NaN
# mean             22.102150          39.326360    24.675137     2.495192
# std               1.574066          47.455314    43.596000     1.114098
# min              14.700000           0.000000     0.000000     1.000000
# 25%              21.100000           8.700000     5.000000     1.750000
# 50%              22.200000          23.850000    12.000000     2.500000
# 75%              23.300000          53.900000    28.000000     3.000000
# max              25.600000         543.300000   461.000000     4.000000
#
#               month          day
# count   1456.000000  1456.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# first           NaN          NaN
# last            NaN          NaN
# mean       6.418269    15.289835
# std        3.451806     8.757900
# min        1.000000     1.000000
# 25%        3.750000     8.000000
# 50%        6.500000    15.000000
# 75%        9.000000    23.000000
# max       12.000000    30.000000
#
# [13 rows x 28 columns]

# %%
# check summary of the submission data
submit.describe(include='all')
# Out:
#        city         year  weekofyear      week_start_date     ndvi_ne  \
# count   416   416.000000  416.000000                  416  373.000000
# unique    2          NaN         NaN                  269         NaN
# top      sj          NaN         NaN  2010-12-24 00:00:00         NaN
# freq    260          NaN         NaN                    2         NaN
# first   NaN          NaN         NaN  2008-04-29 00:00:00         NaN
# last    NaN          NaN         NaN  2013-06-25 00:00:00         NaN
# mean    NaN  2010.766827   26.439904                  NaN    0.126050
# std     NaN     1.434835   14.978257                  NaN    0.164353
# min     NaN  2008.000000    1.000000                  NaN   -0.463400
# 25%     NaN  2010.000000   13.750000                  NaN   -0.001500
# 50%     NaN  2011.000000   26.000000                  NaN    0.110100
# 75%     NaN  2012.000000   39.000000                  NaN    0.263329
# max     NaN  2013.000000   53.000000                  NaN    0.500400
#
#            ndvi_nw     ndvi_se     ndvi_sw  precipitation_amt_mm  \
# count   405.000000  415.000000  415.000000            414.000000
# unique         NaN         NaN         NaN                   NaN
# top            NaN         NaN         NaN                   NaN
# freq           NaN         NaN         NaN                   NaN
# first          NaN         NaN         NaN                   NaN
# last           NaN         NaN         NaN                   NaN
# mean      0.126803    0.207702    0.201721             38.354324
# std       0.141420    0.079102    0.092028             35.171126
# min      -0.211800    0.006200   -0.014671              0.000000
# 25%       0.015975    0.148670    0.134079              8.175000
# 50%       0.088700    0.204171    0.186471             31.455000
# 75%       0.242400    0.254871    0.253243             57.772500
# max       0.649000    0.453043    0.529043            169.340000
#
#         reanalysis_air_temp_k     ...      reanalysis_tdtr_k  \
# count              414.000000     ...             414.000000
# unique                    NaN     ...                    NaN
# top                       NaN     ...                    NaN
# freq                      NaN     ...                    NaN
# first                     NaN     ...                    NaN
# last                      NaN     ...                    NaN
# mean               298.818295     ...               5.124569
# std                  1.469501     ...               3.542870
# min                294.554286     ...               1.485714
# 25%                297.751429     ...               2.446429
# 50%                298.547143     ...               2.914286
# 75%                300.240357     ...               8.171429
# max                301.935714     ...              14.485714
#
#         station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# count           404.000000               404.000000          413.000000
# unique                 NaN                      NaN                 NaN
# top                    NaN                      NaN                 NaN
# freq                   NaN                      NaN                 NaN
# first                  NaN                      NaN                 NaN
# last                   NaN                      NaN                 NaN
# mean             27.369587                 7.810991           32.534625
# std               1.232608                 2.449718            1.920429
# min              24.157143                 4.042857           27.200000
# 25%              26.514286                 5.928571           31.100000
# 50%              27.483333                 6.642857           32.800000
# 75%              28.319048                 9.812500           33.900000
# max              30.271429                14.725000           38.400000
#
#         station_min_temp_c  station_precip_mm  total_cases     quarter  \
# count           407.000000         411.000000        416.0  416.000000
# unique                 NaN                NaN          NaN         NaN
# top                    NaN                NaN          NaN         NaN
# freq                   NaN                NaN          NaN         NaN
# first                  NaN                NaN          NaN         NaN
# last                   NaN                NaN          NaN         NaN
# mean             22.368550          34.278589          0.0    2.492788
# std               1.731437          34.655966          0.0    1.112880
# min              14.200000           0.000000          0.0    1.000000
# 25%              21.200000           9.100000          0.0    1.750000
# 50%              22.200000          23.600000          0.0    2.500000
# 75%              23.300000          47.750000          0.0    3.000000
# max              26.700000         212.000000          0.0    4.000000
#
#              month         day
# count   416.000000  416.000000
# unique         NaN         NaN
# top            NaN         NaN
# freq           NaN         NaN
# first          NaN         NaN
# last           NaN         NaN
# mean      6.415865   15.271635
# std       3.452624    8.762778
# min       1.000000    1.000000
# 25%       3.750000    8.000000
# 50%       6.500000   15.000000
# 75%       9.000000   23.000000
# max      12.000000   30.000000
#
# [13 rows x 28 columns]

# %%
# Check if there is any NA in training data
training.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# station_min_temp_c                        14
# station_precip_mm                         22
# total_cases                                0
# quarter                                    0
# month                                      0
# day                                        0
# dtype: int64

# %%
# Check if there is any NA in submission data
submit.isnull().sum()
# Out:
# city                                      0
# year                                      0
# weekofyear                                0
# week_start_date                           0
# ndvi_ne                                  43
# ndvi_nw                                  11
# ndvi_se                                   1
# ndvi_sw                                   1
# precipitation_amt_mm                      2
# reanalysis_air_temp_k                     2
# reanalysis_avg_temp_k                     2
# reanalysis_dew_point_temp_k               2
# reanalysis_max_air_temp_k                 2
# reanalysis_min_air_temp_k                 2
# reanalysis_precip_amt_kg_per_m2           2
# reanalysis_relative_humidity_percent      2
# reanalysis_sat_precip_amt_mm              2
# reanalysis_specific_humidity_g_per_kg     2
# reanalysis_tdtr_k                         2
# station_avg_temp_c                       12
# station_diur_temp_rng_c                  12
# station_max_temp_c                        3
# station_min_temp_c                        9
# station_precip_mm                         5
# total_cases                               0
# quarter                                   0
# month                                     0
# day                                       0
# dtype: int64

# %%
# Observe histogram of each numeric feature
plt.figure()
training.hist(figsize=(20,20), layout=(8,3))
plt.tight_layout()
plt.show()

# %%
# Explore correlation between variables
plt.figure(figsize=(20,20))
sns.heatmap(training.corr(), xticklabels=training.corr().columns, yticklabels=training.corr().columns, center=0, annot=True)
plt.show()

# %% [markdown]
# ### Step 3: feature engineering
#
# Based on the exploratory data analysis, it seems that the following steps could/should be done:
# 1. generating datetime features
# 2. filling NAs
# 3. removing highly correlated features
# 4. one-hot encoding for categorical features
#
# For step 2, since the NA values for each column are weather related data, it makes sense to fillna in groups of city and month.
# And as the NA values only accounts for less than 10% of the total data for each column, a naive method, median would be used.

# %%
# generating date_time features
training['week_start_date'] = pd.to_datetime(training['week_start_date'], format='%Y-%m-%d')
training['quarter'] = training.week_start_date.dt.quarter
training['month'] = training.week_start_date.dt.month
training['day'] = training.week_start_date.dt.day

submit['week_start_date'] = pd.to_datetime(submit['week_start_date'], format='%Y-%m-%d')
submit['quarter'] = submit.week_start_date.dt.quarter
submit['month'] = submit.week_start_date.dt.month
submit['day'] = submit.week_start_date.dt.day

# %%
# fillna via naive method, median, grouped by city and month
training = training.groupby(['city', 'month'], as_index=False).apply(lambda x: x.fillna(x.median())).reset_index(drop=True)
submit = submit.groupby(['city', 'month'], as_index=False).apply(lambda x: x.fillna(x.median())).reset_index(drop=True)
# Out:
# (1456, 28)

# %%
# Remove some highly correlated non-datetime related features (absolute correlation > 0.9)
features_to_remove = ['reanalysis_sat_precip_amt_mm', 'reanalysis_specific_humidity_g_per_kg', 'reanalysis_avg_temp_k', 'reanalysis_tdtr_k']
training.drop(features_to_remove, axis=1, inplace=True)
submit.drop(features_to_remove, axis=1, inplace=True)

# %%
# one-hot encoding for categorical data: city
training = pd.concat([pd.get_dummies(training.city).astype(int), training], axis=1)
submit = pd.concat([pd.get_dummies(submit.city).astype(int), submit], axis=1)

# %% [markdown]
# ### Step 4: train a model and test result simply using training data
#
# This step helps us understand the accuracy of our model before using it to predict the 'submit' dataset

# %%
# drop week_start_date before training
training.drop(['week_start_date'], axis=1, inplace=True)
submit.drop(['week_start_date'], axis=1, inplace=True)

# %%
# train test split for train, test and cv and then drop categorical variable: city
X_train, X_test, y_train, y_test = train_test_split(training.drop(['total_cases'], axis=1), training.total_cases, test_size=0.2, stratify=training.city, random_state=123)
X_train, X_cv, y_train, y_cv = train_test_split(X_train, y_train, test_size=0.25, stratify=X_train.city, random_state=123)

X_train.drop('city', axis=1, inplace=True)
X_cv.drop('city', axis=1, inplace=True)
X_test.drop('city', axis=1, inplace=True)

# %%
# train the model
model = CatBoostRegressor(iterations = 4000, learning_rate = 0.3, loss_function='MAE', eval_metric='MAE', use_best_model=True, random_seed=123)
model.fit(X_train, y_train, eval_set=(X_cv, y_cv))

# %%
# observe result
y_pred = model.predict(X_test)
print('Mean Absolute Error:', MAE(y_test, y_pred))

# %%
# observe features importance
pd.DataFrame(data={'features':X_train.columns, 'importance':model.feature_importances_}).plot.bar(x='features', y='importance')
plt.show()

# %% [markdown]
# ### Step 5: train the model again using all training data and do prediction for the 'submit' set

# %%
# train test split for train, and cv
X_train, X_cv, y_train, y_cv = train_test_split(training.drop(['total_cases'], axis=1), training.total_cases, test_size=0.3, stratify=training.city, random_state=123)
X_train.drop('city', axis=1, inplace=True)
X_cv.drop('city', axis=1, inplace=True)

# %%
# build model
model = CatBoostRegressor(iterations = 4000, learning_rate = 0.3, loss_function='MAE', eval_metric='MAE', use_best_model=True, random_seed=123)
model.fit(X_train, y_train, eval_set=(X_cv, y_cv))

# %%
# do prediction on the 'submit' data and save as csv for final submission
submit_Y.total_cases = model.predict(submit.drop(['total_cases', 'city'], axis=1))
submit_Y.to_csv('submission.csv', index=False)
